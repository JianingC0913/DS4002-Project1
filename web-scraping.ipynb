# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ### tesing part of the code

# %%
html_test="https://www.boxofficemojo.com/year/2000/?grossesOption=totalGrosses"
req = requests.get(html_test)
data = BeautifulSoup(req.text, 'html')

div = data.find('div', class_="a-section imdb-scroll-table-inner")
#print(div)
#print("div printed, start printing table")
tbl=div.find('table')
#print(tbl)
result=list()
for ele_a in tbl.find_all('a'):
  result.append(str(ele_a.get_text()))

result=result[7:]
top_10_2000 = list()
for i in range(0,10):
  top_10_2000.append(result[2*i])
#print(top_10_2000)

#print(result)

# %% [markdown]
# ### code for getting top 10 movies in each year (2000-2023)

# %%
html_part1 = "https://www.boxofficemojo.com/year/"
year_list = [year for year in range(2000, 2024)]
html_part3 = "/?grossesOption=totalGrosses"
result = list()
for ele in year_list:
    html = html_part1 + str(ele) + html_part3
    req = requests.get(html)
    data = BeautifulSoup(req.text, 'html')

    #find the corresponding div
    div = data.find('div', class_="a-section imdb-scroll-table-inner")
    #print(div)
    #print("div printed, start printing table")

    #find corresponding table
    tbl=div.find('table')
    #print(tbl)

    #create a list for storing our scraped text
    raw_result=list()
    for ele_a in tbl.find_all('a'):
        raw_result.append(str(ele_a.get_text()))

    raw_result=raw_result[7:]
    yearly=list()
    yearly.append(str(ele))
    for i in range(0,10):
        yearly.append(raw_result[2*i])
    result.append(yearly)

df = pd.DataFrame(result)
df
# Out:
#       0                                              1   \
# 0   2000                 How the Grinch Stole Christmas
# 1   2001          Harry Potter and the Sorcerer's Stone
# 2   2002                                     Spider-Man
# 3   2003  The Lord of the Rings: The Return of the King
# 4   2004                                        Shrek 2
# 5   2005   Star Wars: Episode III - Revenge of the Sith
# 6   2006     Pirates of the Caribbean: Dead Man's Chest
# 7   2007                                   Spider-Man 3
# 8   2008                                The Dark Knight
# 9   2009                                         Avatar
# 10  2010                                    Toy Story 3
# 11  2011   Harry Potter and the Deathly Hallows: Part 2
# 12  2012                                   The Avengers
# 13  2013                The Hunger Games: Catching Fire
# 14  2014                                American Sniper
# 15  2015     Star Wars: Episode VII - The Force Awakens
# 16  2016                   Rogue One: A Star Wars Story
# 17  2017        Star Wars: Episode VIII - The Last Jedi
# 18  2018                                  Black Panther
# 19  2019                              Avengers: Endgame
# 20  2020                              Bad Boys for Life
# 21  2021                        Spider-Man: No Way Home
# 22  2022                              Top Gun: Maverick
# 23  2023                                         Barbie
#
#                                                    2   \
# 0                                           Cast Away
# 1   The Lord of the Rings: The Fellowship of the Ring
# 2               The Lord of the Rings: The Two Towers
# 3                                        Finding Nemo
# 4                                        Spider-Man 2
# 5   The Chronicles of Narnia: The Lion, the Witch ...
# 6                                 Night at the Museum
# 7                                     Shrek the Third
# 8                                            Iron Man
# 9                 Transformers: Revenge of the Fallen
# 10                                Alice in Wonderland
# 11                     Transformers: Dark of the Moon
# 12                              The Dark Knight Rises
# 13                                         Iron Man 3
# 14              The Hunger Games: Mockingjay - Part 1
# 15                                     Jurassic World
# 16                                       Finding Dory
# 17                               Beauty and the Beast
# 18                             Avengers: Infinity War
# 19                                      The Lion King
# 20                                 Sonic the Hedgehog
# 17                     Spider-Man: Homecoming
# 18                                 Deadpool 2
# 19                             Captain Marvel
# 20                       The Call of the Wild
# 21                                   Eternals
# 22                   Minions: The Rise of Gru
# 23                         The Little Mermaid
#
#                                        7   \
# 0                        Meet the Parents
# 1                            Pearl Harbor
# 2             Austin Powers in Goldmember
# 3                                     Elf
# 4                  The Day After Tomorrow
# 5       Charlie and the Chocolate Factory
# 6                              Happy Feet
# 7                    The Bourne Ultimatum
# 8                                Twilight
# 9                               Star Trek
# 10                          Despicable Me
# 11   Mission: Impossible - Ghost Protocol
# 12                 The Amazing Spider-Man
# 13                    Monsters University
# 14        Transformers: Age of Extinction
# 15  The Hunger Games: Mockingjay - Part 2
# 16                               Zootopia
# 17                                     It
# 18                             The Grinch
# 19              Spider-Man: Far from Home
# 20                                 Onward
# 21                                 Sing 2
# 22                             The Batman
# 23      Ant-Man and the Wasp: Quantumania
#
#                                      8   \
# 0                                 X-Men
# 1                        Ocean's Eleven
# 2                       Men in Black II
# 3    Terminator 3: Rise of the Machines
# 4                  The Bourne Supremacy
# 5                         Batman Begins
# 6                 Ice Age: The Meltdown
# 7    National Treasure: Book of Secrets
# 8           Madagascar: Escape 2 Africa
# 9                        The Blind Side
# 10                  Shrek Forever After
# 11                               Cars 2
# 12                                Brave
# 13  The Hobbit: The Desolation of Smaug
# 14                           Maleficent
# 15                          The Martian
# 16   Batman v Superman: Dawn of Justice
# 17                       Thor: Ragnarok
# 18        Mission: Impossible - Fallout
# 19                              Aladdin
# 20                The Croods: A New Age
# 21                       No Time to Die
# 22               Thor: Love and Thunder
# 23                 John Wick: Chapter 4
#
#                                          9   \
# 0                               Scary Movie
# 1                         Jurassic Park III
# 2                                   Ice Age
# 3                    The Matrix Revolutions
# 4                         National Treasure
# 5                                Madagascar
# 6                             Casino Royale
# 7                   Alvin and the Chipmunks
# 8                         Quantum of Solace
# 9   Alvin and the Chipmunks: The Squeakquel
# 10                 How to Train Your Dragon
# 11       Sherlock Holmes: A Game of Shadows
# 12                                      Ted
# 13                         Fast & Furious 6
# 14               X-Men: Days of Future Past
# 15                               Cinderella
# 16                            Suicide Squad
# 17                          Despicable Me 3
# 18                     Ant-Man and the Wasp
# 19                                    Joker
# 20                                    Tenet
# 21                    A Quiet Place Part II
# 22                     Sonic the Hedgehog 2
# 23                         Sound of Freedom
#
#                                        10
# 0                       What Lies Beneath
# 1                      Planet of the Apes
# 2                                 Chicago
# 3                    Cheaper by the Dozen
# 4                       The Polar Express
# 5                        Mr. & Mrs. Smith
# 6                The Pursuit of Happyness
# 7                                     300
# 8                     Horton Hears a Who!
# 9                         Sherlock Holmes
# 10                                Tangled
# 11                                   Thor
# 12     Madagascar 3: Europe's Most Wanted
# 13              Oz the Great and Powerful
# 14                             Big Hero 6
# 15                                Spectre
# 16                                   Sing
# 17                         Justice League
# 18                      Bohemian Rhapsody
# 19                Jumanji: The Next Level
# 20                      Wonder Woman 1984
# 21                Ghostbusters: Afterlife
# 22           Puss in Boots: The Last Wish
# 23  Indiana Jones and the Dial of Destiny
